# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn import  metrics
from sklearn.model_selection import KFold

# %%
np.random.seed(15)
n_samples = 100
true_fun = lambda X: np.cos(2*np.pi*X)
X = np.random.choice(np.linspace(0,2,300),n_samples)
y = true_fun(X) + np.random.randn(n_samples) * 0.1
X = np.vstack(X)

# %%
plt.figure(figsize=(6,6));
plt.scatter(X, y,  color='black')
plt.show()

# %% [markdown]
# Do walidacji modeli zastosujemy k-krotną walidację krzyżową (k-fold cross-validation)

# %%
kf = KFold(n_splits=5,shuffle=True,random_state=10)
MSE1_train = 0
MSE2_train = 0
MSE3_train = 0
MSE1_test = 0
MSE2_test = 0
MSE3_test = 0
fig, ax = plt.subplots(2,3,figsize=(15,15))
k = 0
for train_index, test_index in kf.split(X):
    #utworzenie zmiennych X_train, X_test, y_train, y_test
    ...
    
    # Dopasowanie trzech modeli
    mdl1 = make_pipeline(PolynomialFeatures(3), LinearRegression())
    mdl1.fit(X_train, y_train)
    mdl2 = make_pipeline(PolynomialFeatures(8), LinearRegression())
    mdl2.fit(X_train, y_train)
    mdl3 = make_pipeline(PolynomialFeatures(35), LinearRegression())
    mdl3.fit(X_train, y_train)
    # Policzenie i zsumowanie MSE dla danych trenujących i testowych
    ...
    
    # wizualizacja otrzymanych dopasowań
    ...
    
    k+=1
plt.show()

print('Train MSE')
print(MSE1_train)
print(MSE2_train)
print(MSE3_train)
print('Test MSE')
print(MSE1_test)
print(MSE2_test)
print(MSE3_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2158653dc2f8> in <module>
#      14     # Dopasowanie trzech modeli
#      15     mdl1 = make_pipeline(PolynomialFeatures(3), LinearRegression())
# ---> 16     mdl1.fit(X_train, y_train)
#      17     mdl2 = make_pipeline(PolynomialFeatures(8), LinearRegression())
#      18     mdl2.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined
